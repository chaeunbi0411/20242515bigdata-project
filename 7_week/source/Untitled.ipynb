# %%
import pandas as pd
import numpy as np
import os

# %%
print("=" * 65)
print("  [실습 3] CSIC 2010 HTTP 데이터 로드 및 기본 탐색")
print("=" * 65)

# Jupyter 셀 모드에서도 동작하도록 __file__ 처리
try:
    SCRIPT_DIR = os.path.dirname(os.path.abspath(__file__))
except NameError:
    SCRIPT_DIR = os.getcwd()

data_path = os.path.join(SCRIPT_DIR, "csic_database.csv")

if not os.path.exists(data_path):
    print(f"\n  !! csic2010_requests.csv 파일이 없습니다.")
    print(f"  >> 먼저 download_csic2010.py를 실행하세요.")
    exit()

df = pd.read_csv(data_path)

print(f"\n  데이터 로드 완료!")
print(f"  파일: {data_path}")
print(f"  크기: {df.shape[0]:,}행 x {df.shape[1]}열")
# Out:
# ...
#   [실습 3] CSIC 2010 HTTP 데이터 로드 및 기본 탐색
# ...
#
#   데이터 로드 완료!
#   파일: C:\Users\6-112\Desktop\빅데이터분석프로그래밍\bigdata-project-a-20242515\7_week\source\csic_database.csv
#   크기: 61,065행 x 17열

# %%
df.shape
# Out:
# (61065, 17)

# %%
df.describe()
# Out:
#        classification
# count    61065.000000
# mean         0.410464
# std          0.491922
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          1.000000
# max          1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61065 entries, 0 to 61064
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   label            61065 non-null  object
#  1   Method           61065 non-null  object
#  2   User-Agent       61065 non-null  object
#  3   Pragma           61065 non-null  object
#  4   Cache-Control    61065 non-null  object
#  5   Accept           60668 non-null  object
#  6   Accept-encoding  61065 non-null  object
#  7   Accept-charset   61065 non-null  object
#  8   language         61065 non-null  object
#  9   host             61065 non-null  object
#  10  cookie           61065 non-null  object
#  11  content-type     17977 non-null  object
#  12  connection       61065 non-null  object
#  13  lenght           17977 non-null  object
#  14  content          17977 non-null  object
#  15  classification   61065 non-null  int64
# ...

# %%
df.tail()
# Out:
#            label Method                                         User-Agent  \
# 61060  Anomalous    GET  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...
# 61061  Anomalous   POST  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...
# 61062  Anomalous    GET  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...
# 61063  Anomalous    GET  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...
# 61064  Anomalous    GET  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...
#
#          Pragma Cache-Control  \
# 61060  no-cache      no-cache
# 61061  no-cache      no-cache
# 61062  no-cache      no-cache
# 61063  no-cache      no-cache
# 61064  no-cache      no-cache
#
#                                                   Accept  \
# 61060  text/xml,application/xml,application/xhtml+xml...
# 61061  text/xml,application/xml,application/xhtml+xml...
# 61062  text/xml,application/xml,application/xhtml+xml...
# 61063  text/xml,application/xml,application/xhtml+xml...
# ...

# %%
df.nunique()
# Out:
# label                  2
# Method                 3
# User-Agent             1
# Pragma                 1
# Cache-Control          1
# Accept                 1
# Accept-encoding        1
# Accept-charset         1
# language               1
# host                   2
# cookie             61065
# content-type           1
# connection             2
# lenght               382
# content            12091
# classification         2
# URL                13498
# dtype: int64

# %%
df.loc[df["content_length"].isna(), "method"].value_counts()
# Out:
# -----------------------------------------------------------------
# KeyError                        Traceback (most recent call last)
# File ~\Desktop\빅데이터분석프로그래밍\bigdata-project-a-20242515\venv\lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'content_length'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                        Traceback (most recent call last)
# Cell In[9], line 1
# ...
